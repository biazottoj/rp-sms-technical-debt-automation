# %% [markdown]
# # RQ3 - How are software artifacts used in the software development?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def to_1D(series):
 return pd.Series([x for _list in series for x in _list])


path = '../data/Step1_artifacts.json'

artifacts_df = pd.read_json(path, orient='index')

tdma_list = ['repayment',
            'monitoring',
            'measurement',
            'identification',
            'communication',
            'prevention',
            'priorization',
            'representation/documentation']

td_types_list = ['code',
                 'design',
                 'architectural',
                 'test',
                 'documentation',
                 'requirements',
                 'build',
                 'infrastructure',
                 'versioning',
                 'satd']

# %% [markdown]
# ### RQ3.1 - What triggers are used to initiate the automation process?

# %%
#Building dataset with triggers, types, and activities
col = ['id','trigger']
col.extend(tdma_list)
col.extend(td_types_list)

data = []
for i in artifacts_df.index:
  row = [i, artifacts_df['trigger'][i]]

  for tda in tdma_list:
    if tda in artifacts_df['tdma'][i]:
      row.append(1)
    else:
      row.append(0)

  for tdt in td_types_list:
    if tdt in artifacts_df['td_type'][i]:
      row.append(1)
    else:
      row.append(0)

  data.append(row)

tdt_tdma_triggers = pd.DataFrame(data, columns=col)

# %%
# Trigger
artifacts_df.loc[:,['name','trigger']].groupby(['trigger']).count()
# Out:
#                    name
# trigger
# Automated Trigger     9
# Both                 81
# Human Trigger        30

# %%
# Software Type x Trigger
artifacts_df.loc[:,['name','trigger', 'type']].groupby(['trigger','type']).count()
# Out:
#                            name
# trigger           type
# Automated Trigger bot         4
#                   tool        5
# Both              library     4
#                   plugin     14
#                   script     20
#                   tool       43
# Human Trigger     plugin     22
#                   tool        8

# %%
# Software Type x Trigger x Could Integrate?
artifacts_df.loc[:,['name','type', 'can-integrated', 'trigger']].groupby(['type','trigger', 'can-integrated']).count()
# Out:
#                                           name
# type    trigger           can-integrated
# bot     Automated Trigger Yes                4
# library Both              Yes                4
# plugin  Both              Yes               14
#         Human Trigger     Yes               22
# script  Both              Yes               20
# tool    Automated Trigger Yes                5
#         Both              Yes               43
#         Human Trigger     No                 8

# %% [markdown]
# ### RQ3.2 - Can the artifacts be integrated?

# %%
artifacts_df.loc[:,['name', 'is-integrated']].groupby(['is-integrated']).count()
# Out:
#                name
# is-integrated
# No               76
# Yes              44

# %%
# Trigger x Is Integrated?

artifacts_df.loc[:,['name','trigger', 'is-integrated']].groupby(['trigger', 'is-integrated']).count()
# Out:
#                                  name
# trigger           is-integrated
# Automated Trigger No                3
#                   Yes               6
# Both              No               56
#                   Yes              25
# Human Trigger     No               17
#                   Yes              13

# %%
# Trigger x Could Integrated?

artifacts_df.loc[:,['name','trigger', 'can-integrated']].groupby(['trigger', 'can-integrated']).count()
# Out:
#                                   name
# trigger           can-integrated
# Automated Trigger Yes                9
# Both              Yes               81
# Human Trigger     No                 8
#                   Yes               22

# %%
artifacts_df.loc[:,['name', 'can-integrated']].groupby(['can-integrated']).count()
# Out:
#                 name
# can-integrated
# No                 8
# Yes              112

# %%
to_1D(artifacts_df["interface-type"]).value_counts()
# Out:
# cli (standard input)                      56
# api (integrates with ide)                 35
# gui                                       26
# api                                       20
# api (integrates with ci)                  12
# api (integrates with github)               8
# api (integrates with another artifact)     4
# dtype: int64

# %%
cumulative = 0
artifacts_df['is-integrated-type-str'] = '-'
for i in artifacts_df.index:
  lista = artifacts_df['is-integrated-type'][i]
  lista.sort()
  artifacts_df['is-integrated-type-str'][i] = str(lista)

for x in artifacts_df['is-integrated-type-str'].unique():
  artifacts_per_interface = []
  for i in artifacts_df.index:
    if x in artifacts_df['is-integrated-type-str'][i]:
      artifacts_per_interface.append(i)
  cumulative += len(artifacts_per_interface)
  print(f'{x}: ({len(artifacts_per_interface)}) {artifacts_per_interface}\n')
print(cumulative)
# Out:
# ['-']: (73) ['A1', 'A2', 'A3', 'A4', 'A8', 'A11', 'A14', 'A15', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A27', 'A29', 'A30', 'A31', 'A32', 'A34', 'A36', 'A37', 'A38', 'A39', 'A46', 'A48', 'A52', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'A64', 'A65', 'A66', 'A67', 'A69', 'A70', 'A71', 'A72', 'A73', 'A75', 'A76', 'A77', 'A79', 'A81', 'A82', 'A85', 'A86', 'A87', 'A89', 'A90', 'A92', 'A93', 'A96', 'A97', 'A98', 'A99', 'A100', 'A102', 'A103', 'A104', 'A106', 'A107', 'A108', 'A110', 'A114']
#
# ['artifact']: (15) ['A5', 'A6', 'A12', 'A13', 'A16', 'A33', 'A35', 'A43', 'A44', 'A50', 'A74', 'A91', 'A105', 'A116', 'A117']
#
# ['artifact', 'development tool']: (8) ['A7', 'A40', 'A42', 'A95', 'A101', 'A109', 'A111', 'A113']
#
# ['repository']: (7) ['A9', 'A51', 'A78', 'A83', 'A84', 'A115', 'A120']
#
# ['artifact', 'repository']: (3) ['A10', 'A94', 'A118']
#
# ['development tool']: (13) ['A17', 'A25', 'A28', 'A41', 'A45', 'A47', 'A49', 'A53', 'A68', 'A80', 'A88', 'A112', 'A119']
#
# ['development tool', 'repository']: (1) ['A26']
#
# 120

# %%
artifacts_df['interface-type-str'] = '-'
for i in artifacts_df.index:
    lista = artifacts_df['interface-type'][i]
    lista.sort()
    artifacts_df['interface-type-str'][i] = str(lista)

cumulative = 0
unique = artifacts_df['interface-type-str'].unique().tolist()
unique.sort()
for x in unique:
    artifacts_per_interface = []
    for i in artifacts_df.index:
        if x in artifacts_df['interface-type-str'][i]:
            artifacts_per_interface.append(i)
    cumulative += len(artifacts_per_interface)
    print(f'{x}: ({len(artifacts_per_interface)}) {artifacts_per_interface}\n')
print(cumulative)
# Out:
# ['api (integrates with another artifact)']: (4) ['A12', 'A33', 'A35', 'A105']
#
# ['api (integrates with ci)', 'api (integrates with github)']: (1) ['A26']
#
# ['api (integrates with ci)', 'api (integrates with ide)']: (1) ['A97']
#
# ['api (integrates with ci)', 'cli (standard input)', 'gui']: (1) ['A71']
#
# ['api (integrates with ci)', 'gui']: (5) ['A11', 'A62', 'A65', 'A67', 'A110']
#
# ['api (integrates with ci)']: (2) ['A21', 'A22']
#
# ['api (integrates with github)', 'cli (standard input)']: (1) ['A78']
#
# ['api (integrates with github)']: (6) ['A8', 'A9', 'A51', 'A84', 'A115', 'A120']
#
# ['api (integrates with ide)', 'cli (standard input)']: (4) ['A30', 'A42', 'A86', 'A92']
#
# ['api (integrates with ide)']: (28) ['A15', 'A23', 'A25', 'A28', 'A31', 'A41', 'A45', 'A47', 'A49', 'A53', 'A56', 'A59', 'A61', 'A64', 'A68', 'A69', 'A70', 'A75', 'A77', 'A82', 'A85', 'A88', 'A98', 'A100', 'A103', 'A107', 'A112', 'A119']
#
# ['api', 'api (integrates with ci)', 'cli (standard input)']: (1) ['A101']
#
# ['api', 'api (integrates with ci)']: (1) ['A106']
#
# ['api', 'api (integrates with ide)']: (2) ['A95', 'A116']
#
# ['api', 'cli (standard input)', 'gui']: (2) ['A1', 'A57']
#
# ['api', 'cli (standard input)']: (8) ['A7', 'A16', 'A20', 'A40', 'A63', 'A74', 'A89', 'A118']
#
# ['api', 'gui']: (3) ['A19', 'A99', 'A117']
#
# ['api']: (3) ['A83', 'A94', 'A113']
#
# ['cli (standard input)', 'gui']: (7) ['A4', 'A13', 'A44', 'A90', 'A93', 'A104', 'A109']
#
# ['cli (standard input)']: (32) ['A2', 'A3', 'A5', 'A6', 'A10', 'A14', 'A17', 'A18', 'A36', 'A37', 'A38', 'A39', 'A43', 'A46', 'A50', 'A52', 'A54', 'A55', 'A58', 'A66', 'A72', 'A73', 'A76', 'A79', 'A80', 'A81', 'A87', 'A91', 'A96', 'A102', 'A111', 'A114']
#
# ['gui']: (8) ['A24', 'A27', 'A29', 'A32', 'A34', 'A48', 'A60', 'A108']
#
# 120

# %%
artifacts_df.loc[artifacts_df['trigger'] == 'Automated Trigger']
# Out:
#                  name                                               link  \
# A8      bettercodehub                    https://bettercodehub.com/about
# A9           breakbot            https://github.com/alien-tools/breakbot
# A21        code scene                              https://codescene.io/
# A22          codeflow                       https://www.getcodeflow.com/
# A26         codesonar            https://www.grammatech.com/codesonar-cc
# A51         fixme-bot                          https://www.fixmebot.app/
# A84   refactoring-bot  https://github.com/Refactoring-Bot/Refactoring...
# A115             todo                           https://todo.jasonet.co/
# A120        weak-satd     https://zenodo.org/record/5643739#.Y2z5BHbMJaQ
#
#       type       input_info      input_fmt         td_type  \
# A8    tool    [source code]  [source code]  [design, code]
# A9     bot    [source code]  [source code]         [build]
# A21   tool    [source code]  [source code]          [code]
# A22   tool    [source code]  [source code]          [code]
# A26   tool    [source code]  [source code]          [code]
# A51    bot  [code comments]  [source code]          [satd]
# A84    bot    [source code]  [source code]  [design, code]
# A115   bot  [code comments]  [source code]          [satd]
# A120  tool    [source code]  [source code]          [satd]
#
#                                                    tdma is-integrated  \
# A8                                     [identification]            No
# A9                                     [identification]           Yes
# A21           [monitoring, measurement, identification]            No
# A22                                    [identification]            No
# A26                                    [identification]           Yes
# A51   [monitoring, identification, representation/do...           Yes
# A84                                         [repayment]           Yes
# A115     [representation/documentation, identification]           Yes
# A120                                   [identification]           Yes
#
#      can-integrated                 maturity  ...  \
# A8              Yes                 Examples  ...
# A9              Yes                 Examples  ...
# A21             Yes                 Examples  ...
# A22             Yes                 Examples  ...
# A26             Yes  Industrial Applications  ...
# A51             Yes                 Examples  ...
# A84             Yes                 Examples  ...
# A115            Yes                 Examples  ...
# A120            Yes                 Examples  ...
#
#                                    programming_language  \
# A8    [java, c#, c++, go, groovy, javascript, python...
# A9                                                  [-]
# A21                                               [+25]
# A22                                        [javascript]
# A26                                       [java, c/c++]
# A51                       [it uses github repositories]
# A84                                              [java]
# A115                                    [not specified]
# A120                                             [java]
#
#      studies_citing_artifact  \
# A8                     [S85]
# A9                    [S170]
# A21             [S102, S105]
# A22                   [S117]
# A26                    [S69]
# A51                   [S142]
# A84                    [S81]
# A115            [S152, S173]
# A120                  [S178]
#
#                                          other_comments            trigger  \
# A8                                   [runs with github]  Automated Trigger
# A9                                   [runs with github]  Automated Trigger
# A21                                  [runs with github]  Automated Trigger
# A22                                  [runs with github]  Automated Trigger
# A26       [can be integrated with ide and repositories]  Automated Trigger
# A51                                  [runs with github]  Automated Trigger
# A84   [the bot analyzes the source code and refactor...  Automated Trigger
# A115                                              [nan]  Automated Trigger
# A120                                              [nan]  Automated Trigger
#
#                                     trigger-description  \
# A8                                  [executes the tool]
# A9    [breaking changes (e.g., pull request with new...
# A21                                  [runs with github]
# A22                                  [runs with github]
# A26                                 [executes the tool]
# A51                  [it is executed after each commit]
# A84   [after each commint, executes the tools (when ...
# A115                 [it is executed after each commit]
# A120                                [executes the tool]
#
#                                          interface-type  \
# A8                       [api (integrates with github)]
# A9                       [api (integrates with github)]
# A21                          [api (integrates with ci)]
# A22                          [api (integrates with ci)]
# A26   [api (integrates with ci), api (integrates wit...
# A51                      [api (integrates with github)]
# A84                      [api (integrates with github)]
# A115                     [api (integrates with github)]
# A120                     [api (integrates with github)]
#
#                   is-integrated-type  \
# A8                               [-]
# A9                      [repository]
# A21                              [-]
# A22                              [-]
# A26   [repository, development tool]
# A51                     [repository]
# A84                     [repository]
# A115                    [repository]
# A120                    [repository]
#
#                               is-integrated-description first_citation  \
# A8                                                  [-]       2,019.00
# A9                               [runs as a github app]       2,022.00
# A21                                                 [-]       2,020.00
# A22                                                 [-]       2,020.00
# A26   [integrated with github, integrated with jenkins]       2,019.00
# A51                            [integrates with github]       2,021.00
# A84   [generates pull requests to propose the refact...       2,019.00
# A115                             [runs as a github app]       2,021.00
# A120                               [run github actions]       2,022.00
#
#                                      interface-type-str
# A8                     ['api (integrates with github)']
# A9                     ['api (integrates with github)']
# A21                        ['api (integrates with ci)']
# A22                        ['api (integrates with ci)']
# A26   ['api (integrates with ci)', 'api (integrates ...
# A51                    ['api (integrates with github)']
# A84                    ['api (integrates with github)']
# A115                   ['api (integrates with github)']
# A120                   ['api (integrates with github)']
#
# [9 rows x 25 columns]
